# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
g_df = pd.read_csv('YTube.csv', encoding='ISO-8859-1')

# %%
g_df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
g_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
g_df.shape
# Out:
# (995, 28)

# %%
df = g_df.drop(columns = ['Unemployment rate'])

# %%
category_views = df.groupby('category')['video views'].mean().sort_values(ascending=False)

# %%
df['category'].value_counts()
# Out:
# Entertainment            241
# Music                    202
# People & Blogs           132
# Gaming                    94
# Comedy                    69
# Film & Animation          46
# Education                 45
# Howto & Style             40
# News & Politics           26
# Science & Technology      17
# Shows                     13
# Sports                    11
# Pets & Animals             4
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           2
# Travel & Events            1
# Name: category, dtype: int64

# %%
plt.figure(figsize = (10,6))
sns.barplot( x = category_views.values, y = category_views.index ,palette="viridis")
plt.xlabel('toplam izlenme')
plt.ylabel('kategoriler')
plt.title('kategorilere gore izlenmeler')

plt.show()

# %%
plt.figure(figsize = (10,6))
sns.barplot( x = category_views.values, y = category_views.index ,palette="viridis")
plt.xlabel('toplam izlenme')
plt.ylabel('kategoriler')
plt.title('kategorilere gore izlenmeler')

plt.show()

# %%
df['Country'].value_counts()
# Out:
# United States           313
# India                   168
# Brazil                   62
# United Kingdom           43
# Mexico                   33
# Indonesia                28
# Spain                    22
# Thailand                 18
# South Korea              17
# Russia                   16
# Canada                   15
# Argentina                13
# Philippines              12
# Colombia                 11
# Australia                 9
# Saudi Arabia              9
# Ukraine                   8
# United Arab Emirates      7
# Germany                   6
# Pakistan                  6
# France                    5
# Japan                     5
# Turkey                    4
# Sweden                    4
# Vietnam                   3
# Jordan                    3
# Netherlands               3
# Singapore                 3
# Chile                     3
# Egypt                     2
# Ecuador                   2
# Iraq                      2
# Italy                     2
# ...

# %%
ulke_ort = df.groupby('Country')['video views'].mean().sort_values(ascending = False).head(10)

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = ulke_ort.values, y = ulke_ort.index, palette='viridis')
plt.title('ulke ortalamasi')
plt.xlabel('ulke degerleri')
plt.ylabel('ulkeler')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 27 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
kanal_abone = df.groupby('channel_type')['subscribers'].mean().sort_values(ascending = False)

# %%
df['channel_type'].value_counts()
# Out:
# Entertainment    304
# Music            216
# People           101
# Games             98
# Comedy            51
# Education         49
# Film              42
# Howto             36
# News              30
# Tech              17
# Sports            13
# Autos              3
# Animals            3
# Nonprofit          2
# Name: channel_type, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.barplot(x = kanal_abone.values, y = kanal_abone.index, palette='viridis')
plt.title('ulke ortalamasi')
plt.xlabel('ulke degerleri')
plt.ylabel('ulkeler')
plt.show()

# %%
last30_subs = df.groupby('channel_type')['subscribers_for_last_30_days'].sum() / 1e6


last30_subs = last30_subs[last30_subs > 0].sort_values(ascending=False)


plt.figure(figsize=(10,5))
last30_subs.plot(kind='bar', color='skyblue')
plt.title("Son 30 Günde Kanal Türlerine Göre Abone Artışı")
plt.ylabel("Abone Sayısı (Milyon)")
plt.xlabel("Kanal Türü")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
country_analysis = df.groupby('Country').agg({
    'subscribers': 'sum',
    'video views': 'sum',
    'highest_yearly_earnings': 'sum',
    'rank': 'count'  
}).sort_values('subscribers', ascending=False).head(10)

# %%
country_analysis
# Out:
#                       subscribers   video views  highest_yearly_earnings  rank
# Country
# United States          7329500000  3.690292e+12             2.179397e+09   313
# India                  4310600000  2.281048e+12             1.791754e+09   168
# Brazil                 1221800000  4.812090e+11             3.478070e+08    62
# United Kingdom          917400000  4.305665e+11             1.759100e+08    43
# Mexico                  626900000  1.982199e+11             8.625057e+07    33
# Indonesia               534100000  1.510107e+11             1.175791e+08    28
# South Korea             481700000  2.255917e+11             3.202286e+08    17
# Russia                  407200000  2.329963e+11             1.387213e+08    16
# Thailand                386500000  2.643180e+11             7.934850e+07    18
# Spain                   385100000  1.325207e+11             4.815941e+07    22
# Canada                  363900000  1.913206e+11             7.424460e+07    15
# ...

# %%
top5 = df.groupby('Country')['subscribers'].sum().nlargest(5)


plt.figure(figsize=(8,8))
plt.pie(data, labels=data.index,autopct='%1.1f%%', 
        startangle=90, colors=sns.color_palette("viridis"),
        wedgeprops={'linewidth': 1, 'edgecolor': 'white'})

plt.title("Abonelerin Ülkelere Göre Dağılımı", fontsize=14)
plt.show()
